# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_sales = pd.read_csv('Stores.csv')
df_sales
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
#lets see the info of dataset 
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
#as from above datset its all int values so now lets check for some missing values
df_sales.isnull().sum()
# Out:
# Store ID                0
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
#no null values found ,dataset is well filled , lets see some stats
df_sales.describe()
# Out:
#         Store ID    Store_Area  Items_Available  Daily_Customer_Count  \
# count  896.000000   896.000000       896.000000            896.000000
# mean   448.500000  1485.409598      1782.035714            786.350446
# std    258.797218   250.237011       299.872053            265.389281
# min      1.000000   775.000000       932.000000             10.000000
# 25%    224.750000  1316.750000      1575.500000            600.000000
# 50%    448.500000  1477.000000      1773.500000            780.000000
# 75%    672.250000  1653.500000      1982.750000            970.000000
# max    896.000000  2229.000000      2667.000000           1560.000000
#
#          Store_Sales
# count     896.000000
# mean    59351.305804
# std     17190.741895
# min     14920.000000
# 25%     46530.000000
# 50%     58605.000000
# 75%     71872.500000
# max    116320.000000

# %%
#lets see som visuals how the data is releated with diff features,since data is not that large lets see some pairplt all together
sns.pairplot(df_sales)
plt.show()

# %%
#from above we see strong linear releation btwn store area and items available,
#which indicateds that it store area is large enough then more items availabel is what it indicates which is very true

# %%
df_sales.corr()
# Out:
#                       Store ID   Store_Area  Items_Available  \
# Store ID               1.000000   -0.058705        -0.055707
# Store_Area            -0.058705    1.000000         0.998891
# Items_Available       -0.055707    0.998891         1.000000
# Daily_Customer_Count  -0.010029   -0.041423        -0.040978
# Store_Sales            0.071486    0.097474         0.098849
#
#                       Daily_Customer_Count  Store_Sales
# Store ID                         -0.010029     0.071486
# Store_Area                       -0.041423     0.097474
# Items_Available                  -0.040978     0.098849
# Daily_Customer_Count              1.000000     0.008629
# Store_Sales                       0.008629     1.000000

# %%
df_sales.drop('Store ID ',axis=1,inplace=True)

# %%
df_sales.head()
# Out:
#    Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0        1659             1961                   530        66490
# 1        1461             1752                   210        39820
# 2        1340             1609                   720        54010
# 3        1451             1748                   620        53730
# 4        1770             2111                   450        46620

# %% [markdown]
# ### now since store area is large then, can it helps to get more sales??

# %%
sns.heatmap(df_sales.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#from corr it can be seen that store area and daily customer count has negative correltions
sns.jointplot(x='Store_Area', y='Daily_Customer_Count', data=df_sales, kind="reg")

# %%
#from above plot the reg line showing downward reletion ,which means the store area doesnt seem to have more daily customers

# %%
sns.jointplot(x='Store_Sales', y='Daily_Customer_Count',data=df_sales,kind="reg")

# %%
df_sales.describe()
# Out:
#         Store_Area  Items_Available  Daily_Customer_Count    Store_Sales
# count   896.000000       896.000000            896.000000     896.000000
# mean   1485.409598      1782.035714            786.350446   59351.305804
# std     250.237011       299.872053            265.389281   17190.741895
# min     775.000000       932.000000             10.000000   14920.000000
# 25%    1316.750000      1575.500000            600.000000   46530.000000
# 50%    1477.000000      1773.500000            780.000000   58605.000000
# 75%    1653.500000      1982.750000            970.000000   71872.500000
# max    2229.000000      2667.000000           1560.000000  116320.000000

# %%
df_sales
# Out:
#      Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1659             1961                   530        66490
# 1          1461             1752                   210        39820
# 2          1340             1609                   720        54010
# 3          1451             1748                   620        53730
# 4          1770             2111                   450        46620
# ..          ...              ...                   ...          ...
# 891        1582             1910                  1080        66390
# 892        1387             1663                   850        82080
# 893        1200             1436                  1060        76440
# 894        1299             1560                   770        96610
# 895        1174             1429                  1110        54340
#
# [896 rows x 4 columns]

# %% [markdown]
# ### Conclusion

# %% [markdown]
# #### as from above all the reletion btwn feature i dont find any positive reletion ,so there isnt any impact on store sales ,
# #### since daily customer counts doesnt impact on more sales but i see very positive reletion btw store area and items availabe whihc is obvious
# #### so if i try to build a model for predictions then i might have to use more data to train a model, as i cannot use small size of data for testing.
